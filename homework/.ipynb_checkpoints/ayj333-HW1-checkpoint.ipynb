# %%
import random

# %%
# monte carlo

def a_pi(n):
    inside = 0
    for _ in range(0, n):
        inside += int((random.uniform(-1,1)**2 + random.uniform(-1,1)**2)**(1/2) < 1)
            
    return (4*inside/n)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#driver code

# create axes
x = np.arange(10, 1000, 20)
y = np.empty(50)

for (i, v) in enumerate(range(10, 1000, 20)):
    # fill error values
    print(b:=a_pi(v))
    y[i] = abs(b - np.pi)
# Out:
# 3.6
# 3.6
# 3.28
# 3.3142857142857145
# 3.3777777777777778
# 3.2
# 3.2615384615384615
# 3.3333333333333335
# 3.388235294117647
# 3.1157894736842104
# 2.9904761904761905
# 3.217391304347826
# 3.216
# 3.096296296296296
# 3.075862068965517
# 3.109677419354839
# 3.2363636363636363
# 3.1314285714285712
# 3.2324324324324323
# 3.1487179487179486
# 3.0341463414634147
# 3.0604651162790697
# 3.137777777777778
# 3.2085106382978723
# 3.110204081632653
# 3.16078431372549
# 3.0943396226415096
# 3.149090909090909
# 3.1789473684210527
# 3.152542372881356
# 3.1672131147540985
# 3.1746031746031744
# 3.1323076923076925
# 3.2298507462686565
# 3.205797101449275
# 3.1380281690140843
# 3.1506849315068495
# 3.2
# 3.090909090909091
# 3.118987341772152
# 3.1209876543209876
# 3.0602409638554215
# 3.124705882352941
# 3.117241379310345
# 3.1595505617977526
# 3.178021978021978
# 3.1010752688172043
# 3.221052631578947
# 3.105154639175258
# 3.139393939393939

# %%
# plotting

plt.figure
plt.xlabel('samples')
plt.ylabel('error')
plt.plot(x, y, label="samples to error")
plt.legend()
plt.show()
