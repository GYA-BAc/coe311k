# %%
def leibniz(iter):
    return 4*sum([(1/(1+2*i))*(i%2*-2+1) for i in range(iter)])

# %%
leibniz(5000)
# Out:
# 3.141392653591791

# %%
import math
for i in range(100, 5001, 100):
    print(f"Error: {abs(leibniz(i) - math.pi)/math.pi}")
# Out:
# Error: 0.00318301929431018
# Error: 0.001591539484045989
# Error: 0.001061030006672841
# Error: 0.0007957734720706582
# Error: 0.000636619135750372
# Error: 0.0005305161085596649
# Error: 0.00045472817682973846
# Error: 0.00039788720230457477
# Error: 0.000353677542155349
# Error: 0.0003183098066059948
# Error: 0.00028937256401525733
# Error: 0.0002652581924342223
# Error: 0.00024485372238193846
# Error: 0.0002273641754167515
# Error: 0.00021220656721108246
# Error: 0.00019894365943672938
# Error: 0.00018724109332290856
# Error: 0.0001768388120132509
# Error: 0.0001675315074430701
# Error: 0.0001591549331452938
# Error: 0.0001515761276852106
# Error: 0.00014468630442799474
# Error: 0.00013839559614847166
# Error: 0.0001326291134867456
# Error: 0.00012732394938037403
# Error: 0.0001224268747737047
# Error: 0.00011789254639482
# Error: 0.00011368209858290424
# Error: 0.0001097620264549851
# Error: 0.00010610329244741256
# Error: 0.00010268060577533156
# Error: 9.94718370035312e-05
# ...
