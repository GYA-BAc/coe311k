# %%
def leibniz(iter):
    total = 0
    for i in range(iter):
        total += (1/(1+2*i))*(i%2*-2+1)
        
    return total*4

# %%
leibniz(5000)
# Out:
# 3.141392653591791

# %%
import math
for i in range(1, 5000, 100):
    print(f"Error: {leibniz(i) - math.pi}")
# Out:
# Error: 0.8584073464102069
# Error: 0.009900747481198291
# Error: 0.004975093593162505
# Error: 0.0033222499690594987
# Error: 0.0024937617089677566
# Error: 0.0019960059959958087
# Error: 0.001663892359180963
# Error: 0.0014265327977933673
# Error: 0.001248438964235099
# Error: 0.0011098775716362752
# Error: 0.0009990007497511222
# Error: 0.0009082650261267311
# Error: 0.0008326393227977569
# Error: 0.000768639394541637
# Error: 0.0007137757834616565
# Error: 0.0006662224443938491
# Error: 0.0006246095580673128
# Error: 0.000587889425981647
# Error: 0.0005552470421554823
# Error: 0.0005260388904870794
# Error: 0.0004997500937324872
# Error: 0.0004759637997930888
# Error: 0.0004543389134012976
# Error: 0.0004345936344112289
# Error: 0.00041649310980140797
# Error: 0.00039984004799409334
# Error: 0.0003844674982880214
# Error: 0.000370233234260553
# Error: 0.0003570153402856491
# Error: 0.00034470871089320454
# Error: 0.00033322224999654537
# Error: 0.00032247661206108447
# ...
