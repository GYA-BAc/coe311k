# %%
def to_bin(num: int):
    while (quot:=int(num/2)):
        print(f"{quot:6.0f} {num%2}")
        num = int(num/2)

# %%
to_bin(2025)
# Out:
#   1012 1
#    506 0
#    253 0
#    126 1
#     63 0
#     31 1
#     15 1
#      7 1
#      3 1
#      1 1
